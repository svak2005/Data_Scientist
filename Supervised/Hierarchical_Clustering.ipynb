# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage,fcluster
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

# %%
X,y_true=make_blobs(n_samples=100,centers=5,cluster_std=1.0,random_state=42)
X=StandardScaler().fit_transform(X)

# %%
Z=linkage(X,method='ward')
plt.figure(figsize=(10,6))
dendrogram(Z)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.axhline(y=6,color='r',linestyle='--')
plt.show()

# %%
max_clusters=5
labels=fcluster(Z,max_clusters,criterion='maxclust')

# %%
plt.figure(figsize=(8,6))
plt.scatter(X[:,0],X[:,1],c=labels,cmap='rainbow')
plt.title('Clustered Data')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.grid(True)
plt.show()

# %%
df=pd.DataFrame(X,columns=['Feature 1','Feature 2'])
df['Cluster']=labels
print(df.head())
# Out:
#    Feature 1  Feature 2  Cluster
# 0  -0.741023  -1.398107        1
# 1   0.863953   0.440724        3
# 2  -0.101167   0.964210        4
# 3   0.595945   0.013993        3
# 4  -1.212395   0.655763        5
